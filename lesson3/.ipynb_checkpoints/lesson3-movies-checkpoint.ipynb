# %%
# !pip3 install pandas numpy matplotlib plotly
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.10/site-packages (1.26.1)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: plotly in /opt/homebrew/lib/python3.10/site-packages (5.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/homebrew/lib/python3.10/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# import necesary libs
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./imdb_top_1000.csv")
print(df.describe())
print("#" * 30)
print(df.dtypes)
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06
# ##############################
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
sampled_data = df.sample(5)
print(sampled_data[['Series_Title', 'Released_Year', 'Genre', 'Director', 'Star1', 'Star2', 'Star3', 'Star4']])
# Out:
#                Series_Title Released_Year                    Genre  \
# 871           The Quiet Man          1952   Comedy, Drama, Romance
# 407  Der Himmel über Berlin          1987  Drama, Fantasy, Romance
# 565    A Night at the Opera          1935   Comedy, Music, Musical
# 523           Carlito's Way          1993   Crime, Drama, Thriller
# 90                Incendies          2010      Drama, Mystery, War
#
#              Director            Star1                      Star2  \
# 871         John Ford       John Wayne             Maureen O'Hara
# 407       Wim Wenders       Bruno Ganz          Solveig Dommartin
# 565          Sam Wood  Edmund Goulding               Groucho Marx
# 523    Brian De Palma        Al Pacino                  Sean Penn
# 90   Denis Villeneuve     Lubna Azabal  Mélissa Désormeaux-Poulin
#
#                    Star3           Star4
# 871     Barry Fitzgerald       Ward Bond
# 407          Otto Sander       Curt Bois
# 565           Chico Marx      Harpo Marx
# 523  Penelope Ann Miller  John Leguizamo
# 90        Maxim Gaudette   Mustafa Kamel

# %%
# print(df["Released_Year"][1:10])
# convert years to numbers
df["Released_Year"] = pd.to_numeric(df["Released_Year"])

# %%
# print(len(df.loc[df["Released_Year"] == "PG"])) #=> 1
print(df.loc[df["Released_Year"] == "PG"])
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 966            PG           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 966        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes        Gross
# 966       269197  173,837,933

# %%
df.loc[966, "Released_Year"] = "1995"
print(df.loc[[966]])
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 966          1995           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 966        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes        Gross
# 966       269197  173,837,933

# %%
# convert years to numbers, after cleanup
df["Released_Year"] = pd.to_numeric(df["Released_Year"])
print(df.dtypes)
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year      int64
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
# filter movies between 1990 and 2020
filtered_movies = df[(df['Released_Year'] >= 1990) & (df['Released_Year'] <= 2020)]
print(filtered_movies[1:10])
# Out:
#                                           Poster_Link  \
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9   https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 13  https://m.media-amazon.com/images/M/MV5BZGMxZT...
#
#                                          Series_Title  Released_Year  \
# 2                                     The Dark Knight           2008
# 5       The Lord of the Rings: The Return of the King           2003
# 6                                        Pulp Fiction           1994
# 7                                    Schindler's List           1993
# 8                                           Inception           2010
# 9                                          Fight Club           1999
# 10  The Lord of the Rings: The Fellowship of the Ring           2001
# 11                                       Forrest Gump           1994
# 13              The Lord of the Rings: The Two Towers           2002
#
#    Certificate  Runtime                      Genre  IMDB_Rating  \
# 2           UA  152 min       Action, Crime, Drama          9.0
# 5            U  201 min   Action, Adventure, Drama          8.9
# 6            A  154 min               Crime, Drama          8.9
# 7            A  195 min  Biography, Drama, History          8.9
# 8           UA  148 min  Action, Adventure, Sci-Fi          8.8
# 9            A  139 min                      Drama          8.8
# 10           U  178 min   Action, Adventure, Drama          8.8
# 11          UA  142 min             Drama, Romance          8.8
# 13          UA  179 min   Action, Adventure, Drama          8.7
#
#                                              Overview  Meta_score  \
# 2   When the menace known as the Joker wreaks havo...        84.0
# 5   Gandalf and Aragorn lead the World of Men agai...        94.0
# 6   The lives of two mob hitmen, a boxer, a gangst...        94.0
# 7   In German-occupied Poland during World War II,...        94.0
# 8   A thief who steals corporate secrets through t...        74.0
# 9   An insomniac office worker and a devil-may-car...        66.0
# 10  A meek Hobbit from the Shire and eight compani...        92.0
# 11  The presidencies of Kennedy and Johnson, the e...        82.0
# 13  While Frodo and Sam edge closer to Mordor with...        87.0
#
#              Director              Star1                 Star2  \
# 2   Christopher Nolan     Christian Bale          Heath Ledger
# 5       Peter Jackson        Elijah Wood       Viggo Mortensen
# 6   Quentin Tarantino      John Travolta           Uma Thurman
# 7    Steven Spielberg        Liam Neeson         Ralph Fiennes
# 8   Christopher Nolan  Leonardo DiCaprio  Joseph Gordon-Levitt
# 9       David Fincher          Brad Pitt         Edward Norton
# 10      Peter Jackson        Elijah Wood          Ian McKellen
# 11    Robert Zemeckis          Tom Hanks          Robin Wright
# 13      Peter Jackson        Elijah Wood          Ian McKellen
#
#                 Star3             Star4  No_of_Votes        Gross
# 2       Aaron Eckhart     Michael Caine      2303232  534,858,444
# 5        Ian McKellen     Orlando Bloom      1642758  377,845,905
# 6   Samuel L. Jackson      Bruce Willis      1826188  107,928,762
# 7        Ben Kingsley  Caroline Goodall      1213505   96,898,818
# 8         Elliot Page      Ken Watanabe      2067042  292,576,195
# 9           Meat Loaf      Zach Grenier      1854740   37,030,102
# 10      Orlando Bloom         Sean Bean      1661481  315,544,750
# 11        Gary Sinise       Sally Field      1809221  330,252,182
# 13    Viggo Mortensen     Orlando Bloom      1485555  342,551,365

# %%
# Group the data by year and genre
grouped = filtered_movies.groupby(['Released_Year', 'Genre']).size().unstack().fillna(0)

# %%
# Stack graph of genres per year

grouped.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Stacked Bar Chart of Movie Genres per Year')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.legend(title='Genres', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/pb/58v9y36s18q9lzkq5tpf6r0r0000gp/T/ipykernel_78923/3612559981.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
single_row = df.loc[69]
print(single_row)
# Out:
# Poster_Link      https://m.media-amazon.com/images/M/MV5BZTcyNj...
# Series_Title                                               Memento
# Released_Year                                                 2000
# Certificate                                                     UA
# Runtime                                                    113 min
# Genre                                            Mystery, Thriller
# IMDB_Rating                                                    8.4
# Overview         A man with short-term memory loss attempts to ...
# Meta_score                                                    80.0
# Director                                         Christopher Nolan
# Star1                                                   Guy Pearce
# Star2                                             Carrie-Anne Moss
# Star3                                               Joe Pantoliano
# Star4                                            Mark Boone Junior
# No_of_Votes                                                1125712
# Gross                                                   25,544,867
# Name: 69, dtype: object

# %%
# single_row.to_frame() is a df.Series.
# Transposing it converts it to a df.DataFrame
updated_row = single_row.to_frame().T.assign(Genre=df['Genre'].str.split(', ')).explode('Genre')
print(updated_row)
# Out:
#                                           Poster_Link Series_Title  \
# 69  https://m.media-amazon.com/images/M/MV5BZTcyNj...      Memento
# 69  https://m.media-amazon.com/images/M/MV5BZTcyNj...      Memento
#
#    Released_Year Certificate  Runtime     Genre IMDB_Rating  \
# 69          2000          UA  113 min   Mystery         8.4
# 69          2000          UA  113 min  Thriller         8.4
#
#                                              Overview Meta_score  \
# 69  A man with short-term memory loss attempts to ...       80.0
# 69  A man with short-term memory loss attempts to ...       80.0
#
#              Director       Star1             Star2           Star3  \
# 69  Christopher Nolan  Guy Pearce  Carrie-Anne Moss  Joe Pantoliano
# 69  Christopher Nolan  Guy Pearce  Carrie-Anne Moss  Joe Pantoliano
#
#                 Star4 No_of_Votes       Gross
# 69  Mark Boone Junior     1125712  25,544,867
# 69  Mark Boone Junior     1125712  25,544,867

# %%
# now, onto the whole shebang
exploded_df = df.assign(Genre=df['Genre'].str.split(', ')).explode('Genre')
print(len(exploded_df))
# Out:
# 2541

# %%
exploded_n_grouped = \
    exploded_df[(exploded_df['Released_Year'] >= 1990) & (exploded_df['Released_Year'] <= 2020)] \
    .groupby(['Released_Year', 'Genre']).size().unstack().fillna(0)

# %%
# Stack graph of genres per year, onto the exploded group
exploded_n_grouped.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Stacked Bar Chart of Movie Genres per Year')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.legend(title='Genres', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
eng = exploded_n_grouped
genre_count = eng.shape[1]
print(genre_count)
colors = mpl.colormaps['tab20']
# Out:
# 20

# %%
def plot_data(dataframe):
    fig, ax = plt.subplots(figsize=(12, 8))
    bottom = np.zeros(len(dataframe.index))
    for i, (colname, col) in enumerate(dataframe.items()):
        ax.bar(grouped.index, col, bottom=bottom, label=colname, color=colors(i))
        bottom += np.array(col)
    
    plt.title('Stacked Bar Chart of Movie Genres per Year (1990 - 2020)')
    plt.xlabel('Year')
    plt.ylabel('Number of Movies')
    plt.legend(title='Genres', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

plot_data(eng)

# %%
# normalize by genre:
# the provided dataset is poor for certain years (e.g. < 20 movies in 2020)
# To normalize the dataset, divide the # of movies in a given genre by the # of movies in that year

movie_count_per_year = filtered_movies['Released_Year'].value_counts()
print(movie_count_per_year)

# %%
normalized_grouped = eng.div(movie_count_per_year, axis=0)
print(normalized_grouped.sample(5))

# %%
plot_data(normalized_grouped)

# %%
df[df["Released_Year"] == 2009][["Series_Title", "Director", "IMDB_Rating"]]
